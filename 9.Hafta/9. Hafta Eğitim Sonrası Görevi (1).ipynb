# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
import random
import time

class Kumanda:
    
    def __init__(self, tv_durum = "Kapalı", tv_ses = 0, tv_kanal_listesi = ["TRT"], tv_kanal = "TRT"):
        self.tv_durum = tv_durum
        self.tv_ses = tv_ses
        self.tv_kanal_listesi = tv_kanal_listesi
        self.tv_kanal = tv_kanal
        
    def tv_ac(self):
        if self.tv_durum == "Açık":
            print("Televizyon zaten açık...")
        else:
            self.tv_durum = "Açık"
            print("Televizyon açılıyor...")
            
    def tv_kapat(self):
        if self.tv_durum == "Kapalı":
            print("Televizyon zaten kapalı...")
        else:
            self.tv_durum = "Kapalı"
            print("Televizyon kapatılıyor...")
            
    def ses_ayarları(self):
        while True:
            cevap = input("Sesi azalt: '<'\nSesi artır: '>'\nÇıkış yapmak için 'q' tuşuna basın.")
            if cevap == "<":
                if self.tv_ses != 0:
                    self.tv_ses -= 1
                    print("Ses:", self.tv_ses)
            elif cevap == ">":
                if self.tv_ses != 31:
                    self.tv_ses += 1
                    print("Ses:", self.tv_ses)
            else:
                print("Ses güncellendi:", self.tv_ses)
                break
    
    def kanal_ekle(self, kanal_ismi):
        print("Kanal ekleniyor...")
        time.sleep(1)
        self.tv_kanal_listesi.append(kanal_ismi)
        print("Kanal eklendi.")
        
    def kanal_sayısı(self):
        print("Televizyon kanal sayısı:", len(self.tv_kanal_listesi))
        
    def rastgele_kanal(self):
        rastgele = random.randint(0, len(self.tv_kanal_listesi)-1)
        self.tv_kanal = self.tv_kanal_listesi[rastgele]
        print("Şu anki kanal:", self.tv_kanal)
        
    def televizyon_bilgileri(self):
        print("Televizyon Durumu:", self.tv_durum)
        print("Televizyon Ses:", self.tv_ses)
        print("Televizyon Kanal Listesi:", self.tv_kanal_listesi)
        print("Şu anki kanal:", self.tv_kanal)
kumanda = Kumanda()

print("""
Televizyon Kumandası

1. Tv Aç
2. Tv Kapat
3. Ses Ayarları
4. Kanal Ekle
5. Kanal Sayısını Öğrenme
6. Rastgele Kanala Geçme
7. Televizyon Bilgileri

Çıkmak için q'ya basın.
""")

while True:
    işlem = input("İşlemi seçin:")
    
    if işlem == "q":
        print("Programdan çıkılıyor")
